# %%
from semanticmatcher.config import Config

config = Config()  # Loads default config.yaml
# Out:
# /Users/minghao/Desktop/personal/SemanticMatcher/semanticmatcher/config.py:73: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
config.get('embedding')
# Out:
# {'provider': 'huggingface', 'model': 'Qwen/Qwen3-Embedding-0.6B'}
