# %%
from geograpy import extraction

e = extraction.Extractor(url='https://en.wikipedia.org/wiki/2012_Summer_Olympics_torch_relay')
e.find_geoEntities()

# You can now access all of the places found by the Extractor
print(e.places)
# Out:
# /Users/minghao/Desktop/personal/SemanticMatcher/.venv/lib/python3.13/site-packages/newspaper/urls.py:103: SyntaxWarning: invalid escape sequence '\.'
#   """
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from geograpy import extraction
#       3 e = extraction.Extractor(url='https://en.wikipedia.org/wiki/2012_Summer_Olympics_torch_relay')
#       4 e.find_geoEntities()
#
# File ~/Desktop/personal/SemanticMatcher/.venv/lib/python3.13/site-packages/geograpy/__init__.py:4
#       1 '''
#       2 main geograpy 3 module
#       3 '''
# ----> 4 from geograpy.extraction import Extractor
#       5 from geograpy.places import PlaceContext
#       6 from geograpy.locator import Locator
#
# File ~/Desktop/personal/SemanticMatcher/.venv/lib/python3.13/site-packages/geograpy/extraction.py:3
#       1 import nltk
#       2 import re
# ----> 3 from newspaper import Article
#       4 from geograpy.labels import Labels
#       6 class Extractor(object):
#
# File ~/Desktop/personal/SemanticMatcher/.venv/lib/python3.13/site-packages/newspaper/__init__.py:10
#       7 __license__ = 'MIT'
#       8 __copyright__ = 'Copyright 2014, Lucas Ou-Yang'
# ---> 10 from .api import (build, build_article, fulltext, hot, languages,
#      11                   popular_urls, Configuration as Config)
#      12 from .article import Article, ArticleException
#      13 from .mthreading import NewsPool
#
# File ~/Desktop/personal/SemanticMatcher/.venv/lib/python3.13/site-packages/newspaper/api.py:14
#      10 __copyright__ = 'Copyright 2014, Lucas Ou-Yang'
#      12 import feedparser
# ---> 14 from .article import Article
#      15 from .configuration import Configuration
#      16 from .settings import POPULAR_URLS, TRENDING_URL
#
# File ~/Desktop/personal/SemanticMatcher/.venv/lib/python3.13/site-packages/newspaper/article.py:15
#      12 import requests
#      14 from . import images
# ---> 15 from . import network
#      16 from . import nlp
#      17 from . import settings
#
# File ~/Desktop/personal/SemanticMatcher/.venv/lib/python3.13/site-packages/newspaper/network.py:14
#      11 import logging
#      12 import requests
# ---> 14 from .configuration import Configuration
#      15 from .mthreading import ThreadPool
#      16 from .settings import cj
#
# File ~/Desktop/personal/SemanticMatcher/.venv/lib/python3.13/site-packages/newspaper/configuration.py:15
#      11 __copyright__ = 'Copyright 2014, Lucas Ou-Yang'
#      13 import logging
# ---> 15 from .parsers import Parser
#      16 from .text import (StopWords, StopWordsArabic, StopWordsChinese,
#      17                    StopWordsKorean, StopWordsHindi, StopWordsJapanese)
#      18 from .version import __version__
#
# File ~/Desktop/personal/SemanticMatcher/.venv/lib/python3.13/site-packages/newspaper/parsers.py:12
#      10 import lxml.etree
#      11 import lxml.html
# ---> 12 import lxml.html.clean
#      13 import re
#      14 from html import unescape
#
# File ~/Desktop/personal/SemanticMatcher/.venv/lib/python3.13/site-packages/lxml/html/clean.py:18
#       8     __all__ = [
#       9         "clean_html",
#      10         "clean",
#    (...)     15         "word_break_html",
#      16     ]
#      17 except ImportError:
# ---> 18     raise ImportError(
#      19         "lxml.html.clean module is now a separate project lxml_html_clean.\n"
#      20         "Install lxml[html_clean] or lxml_html_clean directly."
#      21     ) from None
#
# ImportError: lxml.html.clean module is now a separate project lxml_html_clean.
# Install lxml[html_clean] or lxml_html_clean directly.

# %%
from geograpy import extraction

e = extraction.Extractor(text='United Kingdom')
e.find_geoEntities()

# You can now access all of the places found by the Extractor
print(e.places)
